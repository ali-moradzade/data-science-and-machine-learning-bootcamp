# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../05-seaborn/country_table.csv')

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
df = df.set_index('Countries')

# %%
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy', axis=1))
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis', center=40)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis', center=10)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis')

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop('Life expectancy', axis=1), linewidth=0.5, annot=True, cmap='viridis', col_cluster=False)
