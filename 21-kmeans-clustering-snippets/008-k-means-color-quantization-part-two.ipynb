# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('../data/palm_trees.jpg')

# %%
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
image_as_array.shape # (H, W, C)
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_as_array)

# %%
plt.figure(dpi=200)
plt.imshow(image_as_array)

# %%
# (H, W, C) --> 2D (H*W, C)
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
h, w, c = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h * w, c)

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
len(image_as_array.shape)
# Out:
# 3

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([4, 4, 4, ..., 2, 2, 2], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[ 67.55794132,  61.8884772 ,  62.41074117],
#        [192.42696067, 154.54879903, 108.62853206],
#        [  2.77619497,   2.59520703,   3.72128604],
#        [219.18798183, 135.28365043,  46.6055683 ],
#        [ 71.66385107, 109.7148257 , 137.96487937],
#        [138.12401355, 144.2071993 , 143.60938328]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[ 68,  62,  62],
#        [192, 155, 109],
#        [  3,   3,   4],
#        [219, 135,  47],
#        [ 72, 110, 138],
#        [138, 144, 144]])

# %%
labels
# Out:
# array([4, 4, 4, ..., 2, 2, 2], dtype=int32)

# %%
rgb_codes[labels]
# Out:
# array([[ 72, 110, 138],
#        [ 72, 110, 138],
#        [ 72, 110, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]])

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
np.reshape(rgb_codes[labels], (h, w, c))
# Out:
# array([[[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        [[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        [[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        [[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 68,  62,  62],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        [[ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         ...,
#         [ 72, 110, 138],
#         [ 72, 110, 138],
#         [ 72, 110, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]]])

# %%
plt.figure(dpi=200)
plt.imshow(quantized_image)
