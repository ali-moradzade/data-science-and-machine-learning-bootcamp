# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()

# %%
plt.figure(figsize=(10, 10))

# %%
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1])

# %%
fig = plt.figure()
axes = fig.add_axes([0, 0, 0.5, 0.5])

# %%
fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 0.5])

# %%
x = np.arange(0, 10)
y = x ** 2

fig = plt.figure()
axes = fig.add_axes([0, 0, 1, 1.5])
axes.plot(x, y)
