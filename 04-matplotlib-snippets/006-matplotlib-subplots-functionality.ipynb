# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(0, 10, 11)
b = a ** 4

# %%
x = np.arange(0, 10)
y = 2 * x

# %%
fig, axes = plt.subplots()

# %%
axes
# Out:
# <AxesSubplot:>

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2,)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x, y)
axes[1].plot(a, b)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0].plot(x, y)
axes[1].plot(a, b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4597/518248365.py in <module>
#       1 fig, axes = plt.subplots(nrows=2, ncols=2)
#       2
# ----> 3 axes[0].plot(x, y)
#       4 axes[1].plot(a, b)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2, 2)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
# axes[1].plot(a, b)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[1][1].plot(a, b)

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

# axes[0][0].plot(x, y)
# axes[1][1].plot(a, b)

# %%
axes.shape
# Out:
# (3,)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

for ax in axes:
    ax.plot(x, y)

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

axes[0].plot(x, y)

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)

axes[0].plot(x, y)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[0][1].plot(x, y)
axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[0][1].plot(x, y)
axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

fig.subplots_adjust(wspace=0.9)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[0][1].plot(x, y)
axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

fig.subplots_adjust(wspace=0.5)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[0][1].plot(x, y)
axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

fig.subplots_adjust(wspace=1, hspace=1)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)
axes[0][1].plot(x, y)
axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][1].plot(a, b)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level')

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level', fontsize=16)

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level', fontsize=16)

plt.tight_layout()

fig.savefig('new_subplots.png', bbox_inches='tight')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level', fontsize=16)

plt.tight_layout()

fig.savefig('new_subplots_quality.png', bbox_inches='tight', dpi=2000)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10), dpi=200)

axes[0][0].plot(x, y)

axes[0][1].plot(x, y)
axes[0][1].set_ylabel('0,1 Y LABEL')


axes[1][0].plot(x, y)
axes[1][0].set_xlim(2, 6)

axes[1][1].plot(a, b)
axes[1][1].set_title('TITLE 1,1')

fig.suptitle('Figure Level', fontsize=16)

plt.tight_layout()
